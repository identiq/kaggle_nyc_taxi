# %% [markdown]
# # Kickstarter

# %%
import os
from pathlib import Path
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd    
import seaborn as sns


pd.options.display.max_columns = 100
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# !ls ../../data
# Out:
# NYC_taxi_trip_duration				 ks-projects-201801.csv
# adult						 ml-latest-small
# articles-sharing-and-reading-from-ci-t-deskdrop  titanic
# ks-projects-201612.csv

# %%
# pathlib or os.path: pick one
INPUT_PATH = Path('..', '..', 'data')
DF_PATH = os.path.join(INPUT_PATH, "ks-projects-201801.csv")
DF_PATH
# Out:
# '../../data/ks-projects-201801.csv'

# %%
# !head ../../data/ks-projects-201801.csv # only on UNIX
# Out:
# ID,name,category,main_category,currency,deadline,goal,launched,pledged,state,backers,country,usd pledged,usd_pledged_real,usd_goal_real
# 1000002330,The Songs of Adelaide & Abullah,Poetry,Publishing,GBP,2015-10-09,1000.00,2015-08-11 12:12:28,0.00,failed,0,GB,0.00,0.00,1533.95
# 1000003930,Greeting From Earth: ZGAC Arts Capsule For ET,Narrative Film,Film & Video,USD,2017-11-01,30000.00,2017-09-02 04:43:57,2421.00,failed,15,US,100.00,2421.00,30000.00
# 1000004038,Where is Hank?,Narrative Film,Film & Video,USD,2013-02-26,45000.00,2013-01-12 00:20:50,220.00,failed,3,US,220.00,220.00,45000.00
# 1000007540,ToshiCapital Rekordz Needs Help to Complete Album,Music,Music,USD,2012-04-16,5000.00,2012-03-17 03:24:11,1.00,failed,1,US,1.00,1.00,5000.00
# 1000011046,Community Film Project: The Art of Neighborhood Filmmaking,Film & Video,Film & Video,USD,2015-08-29,19500.00,2015-07-04 08:35:03,1283.00,canceled,14,US,1283.00,1283.00,19500.00
# 1000014025,Monarch Espresso Bar,Restaurants,Food,USD,2016-04-01,50000.00,2016-02-26 13:38:27,52375.00,successful,224,US,52375.00,52375.00,50000.00
# 1000023410,Support Solar Roasted Coffee & Green Energy!  SolarCoffee.co,Food,Food,USD,2014-12-21,1000.00,2014-12-01 18:30:44,1205.00,successful,16,US,1205.00,1205.00,1000.00
# 1000030581,Chaser Strips. Our Strips make Shots their B*tch!,Drinks,Food,USD,2016-03-17,25000.00,2016-02-01 20:05:12,453.00,failed,40,US,453.00,453.00,25000.00
# 1000034518,SPIN - Premium Retractable In-Ear Headphones with Mic,Product Design,Design,USD,2014-05-29,125000.00,2014-04-24 18:14:43,8233.00,canceled,58,US,8233.00,8233.00,125000.00

# %%
df_raw = pd.read_csv(DF_PATH, index_col='ID', parse_dates=['launched', 'deadline'])
df_raw.head()
# Out:
#                                                          name        category  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah          Poetry
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 1000004038                                     Where is Hank?  Narrative Film
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 1000011046  Community Film Project: The Art of Neighborhoo...    Film & Video
#
#            main_category currency   deadline     goal            launched  \
# ID
# 1000002330    Publishing      GBP 2015-10-09   1000.0 2015-08-11 12:12:28
# 1000003930  Film & Video      USD 2017-11-01  30000.0 2017-09-02 04:43:57
# 1000004038  Film & Video      USD 2013-02-26  45000.0 2013-01-12 00:20:50
# 1000007540         Music      USD 2012-04-16   5000.0 2012-03-17 03:24:11
# 1000011046  Film & Video      USD 2015-08-29  19500.0 2015-07-04 08:35:03
#
#             pledged     state  backers country  usd pledged  usd_pledged_real  \
# ID
# 1000002330      0.0    failed        0      GB          0.0               0.0
# 1000003930   2421.0    failed       15      US        100.0            2421.0
# 1000004038    220.0    failed        3      US        220.0             220.0
# 1000007540      1.0    failed        1      US          1.0               1.0
# 1000011046   1283.0  canceled       14      US       1283.0            1283.0
#
#             usd_goal_real
# ID
# 1000002330        1533.95
# 1000003930       30000.00
# 1000004038       45000.00
# 1000007540        5000.00
# 1000011046       19500.00

# %%
df_raw.describe()
# Out:
#                goal       pledged        backers   usd pledged  \
# count  3.786610e+05  3.786610e+05  378661.000000  3.748640e+05
# mean   4.908079e+04  9.682979e+03     105.617476  7.036729e+03
# std    1.183391e+06  9.563601e+04     907.185035  7.863975e+04
# min    1.000000e-02  0.000000e+00       0.000000  0.000000e+00
# 25%    2.000000e+03  3.000000e+01       2.000000  1.698000e+01
# 50%    5.200000e+03  6.200000e+02      12.000000  3.947200e+02
# 75%    1.600000e+04  4.076000e+03      56.000000  3.034090e+03
# max    1.000000e+08  2.033899e+07  219382.000000  2.033899e+07
#
#        usd_pledged_real  usd_goal_real
# count      3.786610e+05   3.786610e+05
# mean       9.058924e+03   4.545440e+04
# std        9.097334e+04   1.152950e+06
# min        0.000000e+00   1.000000e-02
# 25%        3.100000e+01   2.000000e+03
# 50%        6.243300e+02   5.500000e+03
# 75%        4.050000e+03   1.550000e+04
# max        2.033899e+07   1.663614e+08

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378661 entries, 1000002330 to 999988282
# Data columns (total 14 columns):
# name                378657 non-null object
# category            378661 non-null object
# main_category       378661 non-null object
# currency            378661 non-null object
# deadline            378661 non-null datetime64[ns]
# goal                378661 non-null float64
# launched            378661 non-null datetime64[ns]
# pledged             378661 non-null float64
# state               378661 non-null object
# backers             378661 non-null int64
# country             378661 non-null object
# usd pledged         374864 non-null float64
# usd_pledged_real    378661 non-null float64
# usd_goal_real       378661 non-null float64
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 43.3+ MB

# %%
df_raw['state'].value_counts(normalize=True).plot(kind="barh");

# %% [markdown]
# # Preprocessing

# %%
df = df_raw.copy(deep=True)

# %% [markdown]
# ## Categorical encoding

# %%
for c in df_raw.select_dtypes('object').columns:
    if c == 'state':
        continue
    df[c] = df_raw[c].astype('category').cat.codes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378661 entries, 1000002330 to 999988282
# Data columns (total 14 columns):
# name                378661 non-null int32
# category            378661 non-null int16
# main_category       378661 non-null int8
# currency            378661 non-null int8
# deadline            378661 non-null datetime64[ns]
# goal                378661 non-null float64
# launched            378661 non-null datetime64[ns]
# pledged             378661 non-null float64
# state               378661 non-null object
# backers             378661 non-null int64
# country             378661 non-null int8
# usd pledged         374864 non-null float64
# usd_pledged_real    378661 non-null float64
# usd_goal_real       378661 non-null float64
# dtypes: datetime64[ns](2), float64(5), int16(1), int32(1), int64(1), int8(3), object(1)
# memory usage: 32.1+ MB

# %% [markdown]
# ## Missing values

# %%
df_non_zero_backers = df_raw.loc[df_raw['backers'] != 0]
df_non_zero_backers.head()
# Out:
#                                                          name        category  \
# ID
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 1000004038                                     Where is Hank?  Narrative Film
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 1000011046  Community Film Project: The Art of Neighborhoo...    Film & Video
# 1000014025                               Monarch Espresso Bar     Restaurants
#
#            main_category currency   deadline     goal            launched  \
# ID
# 1000003930  Film & Video      USD 2017-11-01  30000.0 2017-09-02 04:43:57
# 1000004038  Film & Video      USD 2013-02-26  45000.0 2013-01-12 00:20:50
# 1000007540         Music      USD 2012-04-16   5000.0 2012-03-17 03:24:11
# 1000011046  Film & Video      USD 2015-08-29  19500.0 2015-07-04 08:35:03
# 1000014025          Food      USD 2016-04-01  50000.0 2016-02-26 13:38:27
#
#             pledged       state  backers country  usd pledged  \
# ID
# 1000003930   2421.0      failed       15      US        100.0
# 1000004038    220.0      failed        3      US        220.0
# 1000007540      1.0      failed        1      US          1.0
# 1000011046   1283.0    canceled       14      US       1283.0
# 1000014025  52375.0  successful      224      US      52375.0
#
#             usd_pledged_real  usd_goal_real
# ID
# 1000003930            2421.0        30000.0
# 1000004038             220.0        45000.0
# 1000007540               1.0         5000.0
# 1000011046            1283.0        19500.0
# 1000014025           52375.0        50000.0

# %%
average_pledged_account = np.mean(
    df_non_zero_backers['usd_pledged_real'] / df_non_zero_backers['backers'])
average_pledged_account
# Out:
# 75.69746482952095

# %% [markdown]
# ### Missing backers imputation
# We have some missing values in the backers columns (0 backers but pledged > 0). We will impute them.

# %%
def impute_backers(row):
    return int(round(row['usd_pledged_real'] / average_pledged_account))

# %%
wrong_indexes = df.loc[(df['backers'] == 0) & (df['usd_pledged_real'] > 0)].index
wrong_indexes
# Out:
# Int64Index([1000694855,  100149523, 1003023003, 1003130892, 1003629045,
#             1004013077, 1004126342, 1004255433, 1004298993, 1004402863,
#             ...
#              994933706,   99613274,   99739483,  997554968,  997793413,
#              997915422,  997971307,  998319149,    9988744,  999610349],
#            dtype='int64', name='ID', length=3082)

# %%
df.loc[df['backers'] == 0, 'backers'] = df.loc[df['backers'] == 0].apply(impute_backers, axis=1)
df.head()
# Out:
#               name  category  main_category  currency   deadline     goal  \
# ID
# 1000002330  326290       108             12         5 2015-10-09   1000.0
# 1000003930  132984        93              6        13 2017-11-01  30000.0
# 1000004038  357882        93              6        13 2013-02-26  45000.0
# 1000007540  338194        90             10        13 2012-04-16   5000.0
# 1000011046   76586        55              6        13 2015-08-29  19500.0
#
#                       launched  pledged  state  backers  country  usd pledged  \
# ID
# 1000002330 2015-08-11 12:12:28      0.0      1        0        9          0.0
# 1000003930 2017-09-02 04:43:57   2421.0      1       15       22        100.0
# 1000004038 2013-01-12 00:20:50    220.0      1        3       22        220.0
# 1000007540 2012-03-17 03:24:11      1.0      1        1       22          1.0
# 1000011046 2015-07-04 08:35:03   1283.0      0       14       22       1283.0
#
#             usd_pledged_real  usd_goal_real
# ID
# 1000002330               0.0        1533.95
# 1000003930            2421.0       30000.00
# 1000004038             220.0       45000.00
# 1000007540               1.0        5000.00
# 1000011046            1283.0       19500.00

# %%
df.loc[wrong_indexes].head()
# Out:
#               name  category  main_category  currency   deadline    goal  \
# ID
# 1000694855  260860        55              6        13 2014-09-20  6500.0
# 100149523    98472        90             10         0 2015-08-25  4500.0
# 1003023003  317133        90             10        13 2015-04-09  3500.0
# 1003130892   60954        90             10        13 2015-11-26  6000.0
# 1003629045   69589        90             10        13 2016-03-21  3000.0
#
#                       launched  pledged  state  backers  country  usd pledged  \
# ID
# 1000694855 2014-08-06 21:28:36   555.00      5      7.0       16          NaN
# 100149523  2015-08-04 12:05:17  4767.00      5     45.0       16          NaN
# 1003023003 2015-03-10 20:06:13  3576.00      5     47.0       16          NaN
# 1003130892 2015-11-02 22:09:19  7007.80      5     93.0       16          NaN
# 1003629045 2016-02-23 03:09:49  3660.38      5     48.0       16          NaN
#
#             usd_pledged_real  usd_goal_real
# ID
# 1000694855            555.00        6500.00
# 100149523            3402.08        3211.53
# 1003023003           3576.00        3500.00
# 1003130892           7007.80        6000.00
# 1003629045           3660.38        3000.00

# %%
df.loc[df['backers'] == 0, 'backers'] = (df.loc[
    df['backers'] == 0, 'usd_pledged_real'] / average_pledged_account)

# %%
df.head(15)
# Out:
#               name  category  main_category  currency   deadline      goal  \
# ID
# 1000002330  326290       108             12         5 2015-10-09    1000.0
# 1000003930  132984        93              6        13 2017-11-01   30000.0
# 1000004038  357882        93              6        13 2013-02-26   45000.0
# 1000007540  338194        90             10        13 2012-04-16    5000.0
# 1000011046   76586        55              6        13 2015-08-29   19500.0
# 1000014025  201812       123              7        13 2016-04-01   50000.0
# 1000023410  287015        58              7        13 2014-12-21    1000.0
# 1000030581   69619        41              7        13 2016-03-17   25000.0
# 1000034518  260057       113              4        13 2014-05-29  125000.0
# 100004195   260944        39              6        13 2014-08-10   65000.0
# 100004721   219101        95             12         1 2013-10-09    2500.0
# 100005484   182239        72             10        13 2013-04-08   12500.0
# 1000055792  305348        32              2        13 2014-10-02    5000.0
# 1000056157  123382        62              8        13 2016-03-25  200000.0
# 1000057089  337539       136              8         5 2017-05-03    5000.0
#
#                       launched   pledged  state  backers  country  \
# ID
# 1000002330 2015-08-11 12:12:28      0.00      1      0.0        9
# 1000003930 2017-09-02 04:43:57   2421.00      1     15.0       22
# 1000004038 2013-01-12 00:20:50    220.00      1      3.0       22
# 1000007540 2012-03-17 03:24:11      1.00      1      1.0       22
# 1000011046 2015-07-04 08:35:03   1283.00      0     14.0       22
# 1000014025 2016-02-26 13:38:27  52375.00      3    224.0       22
# 1000023410 2014-12-01 18:30:44   1205.00      3     16.0       22
# 1000030581 2016-02-01 20:05:12    453.00      1     40.0       22
# 1000034518 2014-04-24 18:14:43   8233.00      0     58.0       22
# 100004195  2014-07-11 21:55:48   6240.57      0     43.0       22
# 100004721  2013-09-09 18:19:37      0.00      1      0.0        3
# 100005484  2013-03-09 06:42:58  12700.00      3    100.0       22
# 1000055792 2014-09-02 17:11:50      0.00      1      0.0       22
# 1000056157 2016-02-09 23:01:12      0.00      1      0.0       22
# 1000057089 2017-04-05 19:44:18  94175.00      3    761.0        9
#
#             usd pledged  usd_pledged_real  usd_goal_real
# ID
# 1000002330         0.00              0.00        1533.95
# 1000003930       100.00           2421.00       30000.00
# 1000004038       220.00            220.00       45000.00
# 1000007540         1.00              1.00        5000.00
# 1000011046      1283.00           1283.00       19500.00
# 1000014025     52375.00          52375.00       50000.00
# 1000023410      1205.00           1205.00        1000.00
# 1000030581       453.00            453.00       25000.00
# 1000034518      8233.00           8233.00      125000.00
# 100004195       6240.57           6240.57       65000.00
# 100004721          0.00              0.00        2406.39
# 100005484      12700.00          12700.00       12500.00
# 1000055792         0.00              0.00        5000.00
# 1000056157         0.00              0.00      200000.00
# 1000057089     57763.78         121857.33        6469.73

# %% [markdown]
# # Train test split
# We use a train test split to validate our results.

# %%
NUM_FEATURES = ['backers', 'usd_pledged_real', 'usd_goal_real']
CAT_FEATURES = ['main_category', 'currency', 'country']

X = df[NUM_FEATURES + CAT_FEATURES]
X.head()
# Out:
#             backers  usd_pledged_real  usd_goal_real  main_category  currency  \
# ID
# 1000002330      0.0               0.0        1533.95             12         5
# 1000003930     15.0            2421.0       30000.00              6        13
# 1000004038      3.0             220.0       45000.00              6        13
# 1000007540      1.0               1.0        5000.00             10        13
# 1000011046     14.0            1283.0       19500.00              6        13
#
#             country
# ID
# 1000002330        9
# 1000003930       22
# 1000004038       22
# 1000007540       22
# 1000011046       22

# %%
y = df['state']
y.head()
# Out:
# ID
# 1000002330      failed
# 1000003930      failed
# 1000004038      failed
# 1000007540      failed
# 1000011046    canceled
# Name: state, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((283995, 6), (283995,), (94666, 6), (94666,))

# %% [markdown]
# # Modeling

# %%
def train_model(model, X, y,):
    X_train, X_test, y_train, y_test = train_test_split(X, y)
    model.fit(X_train, y_train)
    train_acc = accuracy_score(y_train, model.predict(X_train))
    test_acc = accuracy_score(y_test, model.predict(X_test))
    return {
        'train accuracy': train_acc,
        'test accuracy': test_acc
    }

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_train, rf.predict(X_train))
# Out:
# 0.9616120002112714

# %%
accuracy_score(y_test, rf.predict(X_test))
# Out:
# 0.858227874844189

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Feature extraction

# %%
def extract_date_features(df, col):
    X = pd.DataFrame()
    """ Extract features from a date. """
    X[col + '_year'] = df[col].dt.year
    X[col + '_month'] = df[col].dt.month
    X[col + '_week'] = df[col].dt.week
    X[col + '_dow'] = df[col].dt.dayofweek
    X[col + '_hour'] = df[col].dt.hour
    X[col + '_weekday'] = df[col].dt.weekday
    X[col + '_days_in_month'] = df[col].dt.days_in_month
    X[col + '_is_month_start'] = df[col].dt.is_month_start
    X[col + '_is_month_end'] = df[col].dt.is_month_end
    return X

# %%
launched_features = extract_date_features(df, 'launched')
launched_features.head()
# Out:
#             launched_year  launched_month  launched_week  launched_dow  \
# ID
# 1000002330           2015               8             33             1
# 1000003930           2017               9             35             5
# 1000004038           2013               1              2             5
# 1000007540           2012               3             11             5
# 1000011046           2015               7             27             5
#
#             launched_hour  launched_weekday  launched_days_in_month  \
# ID
# 1000002330             12                 1                      31
# 1000003930              4                 5                      30
# 1000004038              0                 5                      31
# 1000007540              3                 5                      31
# 1000011046              8                 5                      31
#
#             launched_is_month_start  launched_is_month_end
# ID
# 1000002330                    False                  False
# 1000003930                    False                  False
# 1000004038                    False                  False
# 1000007540                    False                  False
# 1000011046                    False                  False

# %%
X = pd.concat([X, launched_features], axis=1)
X.head()
# Out:
#             backers  usd_pledged_real  usd_goal_real  main_category  currency  \
# ID
# 1000002330      0.0               0.0        1533.95             12         5
# 1000003930     15.0            2421.0       30000.00              6        13
# 1000004038      3.0             220.0       45000.00              6        13
# 1000007540      1.0               1.0        5000.00             10        13
# 1000011046     14.0            1283.0       19500.00              6        13
#
#             country  year  month  week  dow          ...            \
# ID                                                   ...
# 1000002330        9  2015      8    33    1          ...
# 1000003930       22  2017      9    35    5          ...
# 1000004038       22  2013      1     2    5          ...
# 1000007540       22  2012      3    11    5          ...
# 1000011046       22  2015      7    27    5          ...
#
#             is_month_end  launched_year  launched_month  launched_week  \
# ID
# 1000002330         False           2015               8             33
# 1000003930         False           2017               9             35
# 1000004038         False           2013               1              2
# 1000007540         False           2012               3             11
# 1000011046         False           2015               7             27
#
#             launched_dow  launched_hour  launched_weekday  \
# ID
# 1000002330             1             12                 1
# 1000003930             5              4                 5
# 1000004038             5              0                 5
# 1000007540             5              3                 5
# 1000011046             5              8                 5
#
#             launched_days_in_month  launched_is_month_start  \
# ID
# 1000002330                      31                    False
# 1000003930                      30                    False
# 1000004038                      31                    False
# 1000007540                      31                    False
# 1000011046                      31                    False
#
#             launched_is_month_end
# ID
# 1000002330                  False
# 1000003930                  False
# 1000004038                  False
# 1000007540                  False
# 1000011046                  False
#
# [5 rows x 24 columns]

# %%
X = pd.concat([X, extract_date_features(df, 'deadline')], axis=1)
X.shape
# Out:
# (378661, 33)

# %%
X.head()
# Out:
#             backers  usd_pledged_real  usd_goal_real  main_category  currency  \
# ID
# 1000002330      0.0               0.0        1533.95             12         5
# 1000003930     15.0            2421.0       30000.00              6        13
# 1000004038      3.0             220.0       45000.00              6        13
# 1000007540      1.0               1.0        5000.00             10        13
# 1000011046     14.0            1283.0       19500.00              6        13
#
#             country  year  month  week  dow  hour  weekday  days_in_month  \
# ID
# 1000002330        9  2015      8    33    1    12        1             31
# 1000003930       22  2017      9    35    5     4        5             30
# 1000004038       22  2013      1     2    5     0        5             31
# 1000007540       22  2012      3    11    5     3        5             31
# 1000011046       22  2015      7    27    5     8        5             31
#
#             is_month_start  is_month_end  launched_year  launched_month  \
# ID
# 1000002330           False         False           2015               8
# 1000003930           False         False           2017               9
# 1000004038           False         False           2013               1
# 1000007540           False         False           2012               3
# 1000011046           False         False           2015               7
#
#             launched_week  launched_dow  launched_hour  launched_weekday  \
# ID
# 1000002330             33             1             12                 1
# 1000003930             35             5              4                 5
# 1000004038              2             5              0                 5
# 1000007540             11             5              3                 5
# 1000011046             27             5              8                 5
#
#             launched_days_in_month  launched_is_month_start  \
# ID
# 1000002330                      31                    False
# 1000003930                      30                    False
# 1000004038                      31                    False
# 1000007540                      31                    False
# 1000011046                      31                    False
#
#             launched_is_month_end  deadline_year  deadline_month  \
# ID
# 1000002330                  False           2015              10
# 1000003930                  False           2017              11
# 1000004038                  False           2013               2
# 1000007540                  False           2012               4
# 1000011046                  False           2015               8
#
#             deadline_week  deadline_dow  deadline_hour  deadline_weekday  \
# ID
# 1000002330             41             4              0                 4
# 1000003930             44             2              0                 2
# 1000004038              9             1              0                 1
# 1000007540             16             0              0                 0
# 1000011046             35             5              0                 5
#
#             deadline_days_in_month  deadline_is_month_start  \
# ID
# 1000002330                      31                    False
# 1000003930                      30                     True
# 1000004038                      28                    False
# 1000007540                      30                    False
# 1000011046                      31                    False
#
#             deadline_is_month_end
# ID
# 1000002330                  False
# 1000003930                  False
# 1000004038                  False
# 1000007540                  False
# 1000011046                  False

# %%
def average_pledge(row):
    res = 0
    if row['usd_pledged_real'] > 0 and row['backers'] > 0:
        res = row['usd_pledged_real'] / row['backers']
    return res

X.loc[:, 'average_pledge'] = df.apply(average_pledge, axis='columns')
X.head()
# Out:
# /Users/flo/bin/anaconda3/envs/nibble/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#             backers  usd_pledged_real  usd_goal_real  main_category  currency  \
# ID
# 1000002330      0.0               0.0        1533.95             12         5
# 1000003930     15.0            2421.0       30000.00              6        13
# 1000004038      3.0             220.0       45000.00              6        13
# 1000007540      1.0               1.0        5000.00             10        13
# 1000011046     14.0            1283.0       19500.00              6        13
#
#             country  average_pledge
# ID
# 1000002330        9        0.000000
# 1000003930       22      161.400000
# 1000004038       22       73.333333
# 1000007540       22        1.000000
# 1000011046       22       91.642857

# %%
df.head()
# Out:
#               name  category  main_category  currency  deadline     goal  \
# ID
# 1000002330  326290       108             12         5      2287   1000.0
# 1000003930  132984        93              6        13      3041  30000.0
# 1000004038  357882        93              6        13      1332  45000.0
# 1000007540  338194        90             10        13      1016   5000.0
# 1000011046   76586        55              6        13      2246  19500.0
#
#             launched  pledged  state  backers  country  usd pledged  \
# ID
# 1000002330    243291      0.0      1      0.0        9          0.0
# 1000003930    361974   2421.0      1     15.0       22        100.0
# 1000004038     80408    220.0      1      3.0       22        220.0
# 1000007540     46556      1.0      1      1.0       22          1.0
# 1000011046    235942   1283.0      0     14.0       22       1283.0
#
#             usd_pledged_real  usd_goal_real
# ID
# 1000002330               0.0        1533.95
# 1000003930            2421.0       30000.00
# 1000004038             220.0       45000.00
# 1000007540               1.0        5000.00
# 1000011046            1283.0       19500.00

# %%
df.loc[(df['backers'] == 0) & (df['usd_pledged_real'] > 0)]
# Out:
#                                                          name      category  \
# ID
# 1000694855                      STREETFIGHTERZ WHEELIE MURICA  Film & Video
# 100149523                         Duncan Woods - Chameleon EP         Music
# 1003023003          The Making of Ashley Kelley's Debut Album         Music
# 1003130892                       Butter Side Down Debut Album         Music
# 1003629045                            Chase Goehring debut EP         Music
# 1004013077           Spencer Capier Instrumental Project 2015         Music
# 1004126342  LUKAS LIGETI'S 50TH BIRTHDAY FESTIVAL: ORIGINA...         Music
# 1004255433      The Battle For Breukelen: A Neighborhood Epic  Film & Video
# 1004298993  "Tamboura Plays Violin" - a collection of Pop ...         Music
# 1004402863        Nightingale Noel - An A Cappella Holiday CD         Music
# 1005185256                             Local Music Connection         Music
# 100522240   DO NOT DUPLICATE - Selected by 2015 Devon Film...  Film & Video
# 1006327667                           Letters to the Wild - EP         Music
# 1008671527                          The Fitness Mindset   :-)    Publishing
# 1008675685               Inspired & the Sleep EP - Eyelid Kid         Music
# 1008815806  Into Winter: An Instrumental Christmas Experiment         Music
# 1009154868       Help advance scientific guitar & bass design         Music
# 1009312309                                        Mr. Pickles    Publishing
# 1009774693                Universal Peace | Universal Justice         Music
# 1010217550                               Solarboot-Havel-Tour         Music
# 1010694326                                          Surrender         Music
# 1011508551                               EBENEZER Solo Record         Music
# 1011952280                         NHSOB Summer Festival 2015         Music
# 1012704793                               Life In The Bus Lane  Film & Video
# 1012744036          An Oratorio for our Time - Last Stop Cafe         Music
# 1012807897                                  Juliet Remembered  Film & Video
# 1013389538  Make admission to the London Music Awards cere...         Music
# 1014077376   Joseph in the Well's Debut EP - Indie String Pop         Music
# 1014094330  Water Dissolving Book - Letting Go with Let Go...    Publishing
# 1014100655                       Iron Butterflies & Ugly Fish    Publishing
# ...                                                       ...           ...
# 982023312                             417 "Person with a Gun"  Film & Video
# 982327172   Kalimba The Spirit of Earth Wind and Fire DVD ...         Music
# 982329957              The Atlanta Vocal Project Christmas CD         Music
# 982721469             TAVAPUTS Vinyl Record "Unresting Event"         Music
# 982855910                                 The Gee Que Project         Music
# 982919439                                               Faith  Film & Video
# 983728691                    The Octopodes' 5th Studio Album!         Music
# 985231591                                            TWO FISH  Film & Video
# 986471034      Help Revival finish their new album, Guidance.         Music
# 98744618                           Vinyl for Dancing Pigeons!         Music
# 988763792     Maud Sings Maud: A Musical Betsy-Tacy Companion         Music
# 989218116                    Keep on Movin' - The Debut Album         Music
# 989499289                                           Sojourner         Music
# 989874415                         Love and Soul through Sound         Music
# 991409513                           Chris Copeland's First EP         Music
# 991483230   Support Vocal Synergy's Second Semester and Te...         Music
# 991820324                                   The Blend CD 2015         Music
# 992433603                                   Jonny Come Lately  Film & Video
# 994080962                                     Maximum Coppage  Film & Video
# 994621918                                         Star Sailor  Film & Video
# 994933706                              Whiskey and Holy Water         Music
# 99613274                 Double EP and Music Video Fundraiser         Music
# 99739483                                         No More Fear         Music
# 997554968   Susan Picking: Making Music with Kids in the S...         Music
# 997793413          Whisper Violet - Honors Senior Thesis Film  Film & Video
# 997915422                     Otter's First Full Length Album         Music
# 997971307   EQUUS International Film Festival®, all-equine...  Film & Video
# 998319149                             Emily 2050 - Short Film  Film & Video
# 9988744                                Matthew Stephens Music         Music
# 999610349      Lady Vendredi: Afrofuturist concept 12 inch EP         Music
#
#            main_category currency    deadline     goal             launched  \
# ID
# 1000694855  Film & Video      USD  2014-09-20   6500.0  2014-08-06 21:28:36
# 100149523          Music      AUD  2015-08-25   4500.0  2015-08-04 12:05:17
# 1003023003         Music      USD  2015-04-09   3500.0  2015-03-10 20:06:13
# 1003130892         Music      USD  2015-11-26   6000.0  2015-11-02 22:09:19
# 1003629045         Music      USD  2016-03-21   3000.0  2016-02-23 03:09:49
# 1004013077         Music      CAD  2014-10-10   4000.0  2014-09-10 22:51:01
# 1004126342         Music      USD  2015-06-11   5000.0  2015-05-15 02:12:35
# 1004255433  Film & Video      USD  2015-11-07   6000.0  2015-10-10 18:45:24
# 1004298993         Music      USD  2015-03-28   2750.0  2015-02-11 19:28:27
# 1004402863         Music      USD  2015-12-11   1200.0  2015-11-11 21:02:55
# 1005185256         Music      USD  2015-12-18   1500.0  2015-11-18 21:50:04
# 100522240   Film & Video      GBP  2015-04-10   1500.0  2015-03-11 22:07:00
# 1006327667         Music      USD  2014-10-31   2000.0  2014-10-02 22:48:31
# 1008671527    Publishing      EUR  2015-11-17   8000.0  2015-10-13 15:45:38
# 1008675685         Music      USD  2015-10-30   2000.0  2015-10-04 21:48:11
# 1008815806         Music      USD  2014-10-11   2000.0  2014-09-10 23:23:40
# 1009154868         Music      USD  2016-03-12   5000.0  2016-02-11 01:42:44
# 1009312309    Publishing      USD  2015-05-01   3750.0  2015-04-01 16:36:51
# 1009774693         Music      USD  2014-09-06   2500.0  2014-07-29 23:01:07
# 1010217550         Music      EUR  2015-05-31   2500.0  2015-05-14 23:05:51
# 1010694326         Music      CAD  2015-01-30   5000.0  2014-12-29 01:27:30
# 1011508551         Music      USD  2015-05-30   8000.0  2015-04-20 17:33:24
# 1011952280         Music      GBP  2015-05-15   3000.0  2015-03-31 17:21:17
# 1012704793  Film & Video      USD  2014-12-21   7500.0  2014-11-21 05:09:09
# 1012744036         Music      USD  2016-05-26   5000.0  2016-04-26 19:46:26
# 1012807897  Film & Video      GBP  2016-02-06   6500.0  2016-01-07 13:44:33
# 1013389538         Music      CAD  2015-06-09   3500.0  2015-05-10 15:22:18
# 1014077376         Music      USD  2015-05-01   7500.0  2015-04-01 18:36:53
# 1014094330    Publishing      CAD  2015-08-30   3000.0  2015-07-31 22:28:07
# 1014100655    Publishing      USD  2015-04-15   5000.0  2015-02-14 20:03:56
# ...                  ...      ...         ...      ...                  ...
# 982023312   Film & Video      USD  2015-11-01   8000.0  2015-10-02 02:01:09
# 982327172          Music      USD  2015-05-07   2000.0  2015-03-23 17:10:14
# 982329957          Music      USD  2014-11-14   2500.0  2014-10-15 18:01:45
# 982721469          Music      USD  2014-12-22   1500.0  2014-11-21 06:39:03
# 982855910          Music      USD  2015-04-24   3500.0  2015-03-25 02:44:09
# 982919439   Film & Video      USD  2016-05-06   9000.0  2016-03-07 04:17:33
# 983728691          Music      USD  2016-01-05   8000.0  2015-11-19 23:43:09
# 985231591   Film & Video      USD  2014-05-17   8000.0  2014-04-21 21:52:55
# 986471034          Music      USD  2015-05-02   2500.0  2015-04-03 11:16:00
# 98744618           Music      SEK  2016-04-16  33000.0  2016-03-17 13:42:54
# 988763792          Music      USD  2015-12-03   6500.0  2015-10-04 00:55:19
# 989218116          Music      GBP  2014-11-19   1300.0  2014-10-22 22:22:14
# 989499289          Music      USD  2016-04-11   2500.0  2016-03-12 23:22:51
# 989874415          Music      USD  2015-06-27   3000.0  2015-05-28 17:17:08
# 991409513          Music      USD  2015-02-28   5500.0  2015-01-29 02:58:24
# 991483230          Music      USD  2015-12-20   3400.0  2015-12-05 05:10:10
# 991820324          Music      USD  2015-05-15   8000.0  2015-04-15 00:07:51
# 992433603   Film & Video      USD  2014-12-24   8500.0  2014-11-24 20:47:45
# 994080962   Film & Video      USD  2014-08-19   3000.0  2014-07-18 03:42:11
# 994621918   Film & Video      USD  2016-01-01   8000.0  2015-12-03 20:25:41
# 994933706          Music      USD  2015-05-11   6500.0  2015-03-25 03:55:53
# 99613274           Music      GBP  2015-12-02   3000.0  2015-11-02 09:33:38
# 99739483           Music      GBP  2016-04-17   2500.0  2016-03-17 13:43:26
# 997554968          Music      USD  2015-03-01   8000.0  2015-01-31 20:58:01
# 997793413   Film & Video      USD  2016-05-14   2000.0  2016-04-14 01:27:27
# 997915422          Music      USD  2015-12-31   5000.0  2015-12-01 00:25:06
# 997971307   Film & Video      USD  2015-02-03   7500.0  2014-12-05 04:19:14
# 998319149   Film & Video      CAD  2014-05-23   3000.0  2014-04-08 00:30:09
# 9988744            Music      USD  2016-02-05   5000.0  2016-01-06 21:59:23
# 999610349          Music      GBP  2015-10-19   2000.0  2015-09-21 22:33:18
#
#             pledged       state  backers country  usd pledged  \
# ID
# 1000694855   555.00   undefined        0    N,0"          NaN
# 100149523   4767.00   undefined        0    N,0"          NaN
# 1003023003  3576.00   undefined        0    N,0"          NaN
# 1003130892  7007.80   undefined        0    N,0"          NaN
# 1003629045  3660.38   undefined        0    N,0"          NaN
# 1004013077  4760.00   undefined        0    N,0"          NaN
# 1004126342  6370.00   undefined        0    N,0"          NaN
# 1004255433  6695.00   undefined        0    N,0"          NaN
# 1004298993  2926.00   undefined        0    N,0"          NaN
# 1004402863  1585.00   undefined        0    N,0"          NaN
# 1005185256    69.00   undefined        0    N,0"          NaN
# 100522240    277.00   undefined        0    N,0"          NaN
# 1006327667  2560.00   undefined        0    N,0"          NaN
# 1008671527    30.00   undefined        0    N,0"          NaN
# 1008675685  2079.00   undefined        0    N,0"          NaN
# 1008815806  2085.00   undefined        0    N,0"          NaN
# 1009154868   121.00   undefined        0    N,0"          NaN
# 1009312309   230.00   undefined        0    N,0"          NaN
# 1009774693  2720.00   undefined        0    N,0"          NaN
# 1010217550  2620.00   undefined        0    N,0"          NaN
# 1010694326  5197.00   undefined        0    N,0"          NaN
# 1011508551  8361.00   undefined        0    N,0"          NaN
# 1011952280    34.00   undefined        0    N,0"          NaN
# 1012704793  9329.00   undefined        0    N,0"          NaN
# 1012744036  5170.00  successful        0    N,0"          NaN
# 1012807897  6660.12   undefined        0    N,0"          NaN
# 1013389538   207.00   undefined        0    N,0"          NaN
# 1014077376  7705.00   undefined        0    N,0"          NaN
# 1014094330    66.00   undefined        0    N,0"          NaN
# 1014100655    10.00   undefined        0    N,0"          NaN
# ...             ...         ...      ...     ...          ...
# 982023312    176.00   undefined        0    N,0"          NaN
# 982327172   2086.00   undefined        0    N,0"          NaN
# 982329957   2976.00   undefined        0    N,0"          NaN
# 982721469   1755.00   undefined        0    N,0"          NaN
# 982855910      1.00   undefined        0    N,0"          NaN
# 982919439      2.00      failed        0    N,0"          NaN
# 983728691   8025.00   undefined        0    N,0"          NaN
# 985231591   8562.00   undefined        0    N,0"          NaN
# 986471034    420.00   undefined        0    N,0"          NaN
# 98744618    1105.00   undefined        0    N,0"          NaN
# 988763792   7814.00   undefined        0    N,0"          NaN
# 989218116      2.00   undefined        0    N,0"          NaN
# 989499289     80.00   undefined        0    N,0"          NaN
# 989874415     45.00   undefined        0    N,0"          NaN
# 991409513   5763.00   undefined        0    N,0"          NaN
# 991483230   3435.00   undefined        0    N,0"          NaN
# 991820324   8156.00   undefined        0    N,0"          NaN
# 992433603   9146.00   undefined        0    N,0"          NaN
# 994080962   3175.00   undefined        0    N,0"          NaN
# 994621918   8061.00   undefined        0    N,0"          NaN
# 994933706   6696.00   undefined        0    N,0"          NaN
# 99613274    3517.00   undefined        0    N,0"          NaN
# 99739483    2500.00   undefined        0    N,0"          NaN
# 997554968   8582.00   undefined        0    N,0"          NaN
# 997793413   2300.00  successful        0    N,0"          NaN
# 997915422   6065.26   undefined        0    N,0"          NaN
# 997971307     10.00   undefined        0    N,0"          NaN
# 998319149   3102.00   undefined        0    N,0"          NaN
# 9988744      235.00   undefined        0    N,0"          NaN
# 999610349   2125.00   undefined        0    N,0"          NaN
#
#             usd_pledged_real  usd_goal_real
# ID
# 1000694855            555.00        6500.00
# 100149523            3402.08        3211.53
# 1003023003           3576.00        3500.00
# 1003130892           7007.80        6000.00
# 1003629045           3660.38        3000.00
# 1004013077           4251.14        3572.39
# 1004126342           6370.00        5000.00
# 1004255433           6695.00        6000.00
# 1004298993           2926.00        2750.00
# 1004402863           1585.00        1200.00
# 1005185256             69.00        1500.00
# 100522240             404.18        2188.69
# 1006327667           2560.00        2000.00
# 1008671527             32.06        8550.39
# 1008675685           2079.00        2000.00
# 1008815806           2085.00        2000.00
# 1009154868            121.00        5000.00
# 1009312309            230.00        3750.00
# 1009774693           2720.00        2500.00
# 1010217550           2939.13        2804.51
# 1010694326           4101.82        3946.33
# 1011508551           8361.00        8000.00
# 1011952280             53.41        4712.83
# 1012704793           9329.00        7500.00
# 1012744036           5170.00        5000.00
# 1012807897           9660.05        9427.80
# 1013389538            168.25        2844.83
# 1014077376           7705.00        7500.00
# 1014094330             49.89        2267.57
# 1014100655             10.00        5000.00
# ...                      ...            ...
# 982023312             176.00        8000.00
# 982327172            2086.00        2000.00
# 982329957            2976.00        2500.00
# 982721469            1755.00        1500.00
# 982855910               1.00        3500.00
# 982919439               2.00        9000.00
# 983728691            8025.00        8000.00
# 985231591            8562.00        8000.00
# 986471034             420.00        2500.00
# 98744618              136.19        4067.35
# 988763792            7814.00        6500.00
# 989218116               3.14        2038.70
# 989499289              80.00        2500.00
# 989874415              45.00        3000.00
# 991409513            5763.00        5500.00
# 991483230            3435.00        3400.00
# 991820324            8156.00        8000.00
# 992433603            9146.00        8500.00
# 994080962            3175.00        3000.00
# 994621918            8061.00        8000.00
# 994933706            6696.00        6500.00
# 99613274             5324.59        4541.88
# 99739483             3594.48        3594.48
# 997554968            8582.00        8000.00
# 997793413            2300.00        2000.00
# 997915422            6065.26        5000.00
# 997971307              10.00        7500.00
# 998319149            2845.61        2752.04
# 9988744               235.00        5000.00
# 999610349            3273.36        3080.81
#
# [3082 rows x 14 columns]

# %%
X.head()
# Out:
#             backers  usd_pledged_real  usd_goal_real  main_category  currency  \
# ID
# 1000002330      0.0               0.0        1533.95             12         5
# 1000003930     15.0            2421.0       30000.00              6        13
# 1000004038      3.0             220.0       45000.00              6        13
# 1000007540      1.0               1.0        5000.00             10        13
# 1000011046     14.0            1283.0       19500.00              6        13
#
#             country  average_pledge
# ID
# 1000002330        9        0.000000
# 1000003930       22      161.400000
# 1000004038       22       73.333333
# 1000007540       22        1.000000
# 1000011046       22       91.642857

# %%
# %%time

train_model(rf, X, y)
# Out:
# CPU times: user 10.5 s, sys: 387 ms, total: 10.9 s
# Wall time: 7.33 s
# (0.962207081110583, 0.8585342150296833)

# %% [markdown]
# # Fit after feature engineering

# %%
train_model(rf, X, y)
# Out:
# (0.994017500308104, 0.8637208712737414)

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(max_depth=2, min_samples_split=20)
train_model(dt, X, y)
# Out:
# {'train accuracy': 0.737044666279336, 'test accuracy': 0.7375932224874823}

# %%
from nibble.tree import print_tree, display_tree

# %%
print_tree(dt)
# Out:
# The binary tree structure has 7 nodes and has the following tree structure:
# node=0 test node: go to node 1 if X[:, 0] <= 0 else to node 17.5.
# 	node=1 test node: go to node 2 if X[:, 2] <= 2 else to node 758.864990234375.
# 		node=2 leaf node.
# 		node=3 leaf node.
# 	node=4 test node: go to node 5 if X[:, 2] <= 2 else to node 8154.5146484375.
# 		node=5 leaf node.
# 		node=6 leaf node.

# %%
from IPython.display import Image
Image(display_tree(dt))

# %%
n_estimators = 10
rf = RandomForestClassifier(n_estimators=n_estimators, oob_score=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((283995, 33), (283995,), (94666, 33), (94666,))

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=True, random_state=None, verbose=0, warm_start=False)

# %%
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)

# %%
train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)
print(f"Train accuracy: {train_acc:.3f}")
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# Train accuracy: 0.994
# Test accuracy: 0.866

# %%
rf.oob_score_
# Out:
# 0.802169052272047

# %%
preds = np.stack([t.predict(X_test) for t in rf.estimators_]).T
preds.shape
# Out:
# (94666, 10)

# %%
import scipy

# %%
mode_, count_ = scipy.stats.mode(preds[0, :])
mode_, count_
# Out:
# (array([1.]), array([9]))

# %%
modes_, counts_ = scipy.stats.mode(preds, axis=1)
confidence = pd.DataFrame({
    'pred': np.squeeze(modes_),
    'freq': np.squeeze(counts_) / n_estimators * 100
})
confidence.head()
# Out:
#    pred  freq
# 0   1.0  90.0
# 1   1.0  90.0
# 2   1.0  80.0
# 3   1.0  70.0
# 4   3.0  90.0

# %%
rf.classes_
# Out:
# array(['canceled', 'failed', 'live', 'successful', 'suspended',
#        'undefined'], dtype=object)

# %%
confidence['pred'] = confidence['pred'].apply(lambda p: rf.classes_[int(p)])
confidence.head()
# Out:
#          pred  freq
# 0      failed  90.0
# 1      failed  90.0
# 2      failed  80.0
# 3      failed  70.0
# 4  successful  90.0

# %%
pvt = pd.pivot_table(confidence, values='freq', columns='pred', aggfunc=['mean', 'std'])
pvt
# Out:
#            mean                                                         \
# pred   canceled     failed       live successful  suspended  undefined
# freq  53.381871  80.814623  85.513654  91.310182  44.545455  85.251462
#
#            std
# pred  canceled     failed       live successful suspended  undefined
# freq  8.692414  13.933017  14.416702  11.931014  9.341987  14.055799

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
LABELS = y_train.unique()
LABELS
# Out:
# array(['successful', 'failed', 'canceled', 'undefined', 'live',
#        'suspended'], dtype=object)

# %%
cm = confusion_matrix(y_test, y_test_pred, labels=LABELS)
cm
# Out:
# array([[33047,   401,    31,     0,     9,     1],
#        [  734, 46706,  1971,     3,     9,     7],
#        [  330,  8598,   708,     0,    57,     2],
#        [   23,    16,     0,   852,     0,     0],
#        [    0,     0,     8,     0,   691,     1],
#        [   75,   358,    25,     0,     3,     0]])

# %%
pd.DataFrame(cm, columns=LABELS, index=LABELS)
# Out:
#             successful  failed  canceled  undefined  live  suspended
# successful       33047     401        31          0     9          1
# failed             734   46706      1971          3     9          7
# canceled           330    8598       708          0    57          2
# undefined           23      16         0        852     0          0
# live                 0       0         8          0   691          1
# suspended           75     358        25          0     3          0

# %%
ax = plt.gca()

sns.heatmap(cm, annot=True, fmt='g', ax=ax)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(LABELS, rotation=45)
ax.yaxis.set_ticklabels(LABELS, rotation=0);

# %% [markdown]
# ## Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_scores = cross_val_score(rf, X_train, y_train, cv=5, n_jobs=-1)
cv_scores
# Out:
# array([0.86588264, 0.86367958, 0.86427578, 0.86441663, 0.86210296])

# %%
np.mean(cv_scores), np.std(cv_scores)
# Out:
# (0.8628708333779131, 0.0016560388879801873)

# %% [markdown]
# ### `StratifiedKFold`

# %%
from sklearn.model_selection import StratifiedKFold

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
skf
# Out:
# StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

# %%
cv_scores = cross_val_score(rf, X_train, y_train, cv=skf, n_jobs=-1)
cv_scores
# Out:
# array([0.86324184, 0.86498239, 0.86381802, 0.86378281, 0.86506092])

# %% [markdown]
# ## Tuning hyperparameters

# %%
rf = RandomForestClassifier(n_estimators=20)

# %%
cv_scores = cross_val_score(rf, X_train, y_train, cv=skf, n_jobs=-1)
cv_scores
# Out:
# array([0.87472052, 0.87603873, 0.87478653, 0.87674079, 0.87574829])

# %% [markdown]
# ## Features importance

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf.feature_importances_
# Out:
# array([0.2345229 , 0.24215493, 0.18283761, 0.03036898, 0.01206877,
#        0.01837322, 0.0121724 , 0.00754079, 0.02147101, 0.00976934,
#        0.02570478, 0.0098105 , 0.00380699, 0.00142656, 0.00136147,
#        0.01377297, 0.00855046, 0.02142169, 0.00967018, 0.0261699 ,
#        0.00972849, 0.00374328, 0.00138453, 0.00135403, 0.01744436,
#        0.00983415, 0.02491262, 0.01420724, 0.        , 0.01427211,
#        0.00531667, 0.00270273, 0.00212434])

# %%
fi_dict = {
    'feats': X_train.columns,
    'feature_importance': rf.feature_importances_
}
fi = pd.DataFrame(fi_dict).set_index('feats').sort_values(
    'feature_importance', ascending=False)
fi.head(10)
# Out:
#                   feature_importance
# feats
# usd_pledged_real            0.242155
# backers                     0.234523
# usd_goal_real               0.182838
# main_category               0.030369
# launched_hour               0.026170
# hour                        0.025705
# deadline_week               0.024913
# week                        0.021471
# launched_week               0.021422
# country                     0.018373

# %%
fi.sort_values(
    'feature_importance', ascending=True).tail(10).plot.barh();

# %%
X['currency']
# Out:
# ID
# 1000002330     5
# 1000003930    13
# 1000004038    13
# 1000007540    13
# 1000011046    13
# 1000014025    13
# 1000023410    13
# 1000030581    13
# 1000034518    13
# 100004195     13
# 100004721      1
# 100005484     13
# 1000055792    13
# 1000056157    13
# 1000057089     5
# 1000064368    13
# 1000064918    13
# 1000068480    13
# 1000070642    13
# 1000071625    13
# 1000072011    13
# 1000081649     0
# 1000082254    13
# 1000087442     9
# 1000091520    13
# 1000102741    13
# 1000103948     5
# 1000104688     1
# 1000104953     5
# 100011318     13
#               ..
# 999832803     13
# 99984851      13
# 999865831     13
# 999867839     13
# 99987261      13
# 999877902      1
# 999878813     13
# 999880710     13
# 999884445     13
# 999893629     13
# 99991751       2
# 999929142      4
# 999931480     13
# 999934908     13
# 999941823      5
# 999943841     13
# 999950812     13
# 999955533     13
# 999963618     13
# 99996661      13
# 999969812      1
# 999971898      9
# 999972264     13
# 999975836     13
# 999976312      1
# 999976400     13
# 999977640     13
# 999986353     13
# 999987933     13
# 999988282     13
# Name: currency, Length: 378661, dtype: int8
